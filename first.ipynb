# %%
#----------------------- ASSIGNMENT FOR SMIT ----------------------- #
print("TYPE 00 AS FIRST NUMBER TO EXIT.")
while True:
     user_input_1 = int(input("WRITE FIRST NUMBER : "))
     if user_input_1 == 00: #------------ EXITING CALCULATER ----------------- #
          print("CALCULATER CLOSED!")
          break
     op = input("WRITE THE OPERATION TO PERFORM : ")
     user_input_2 = int(input("WRITE SECOND NUMBER : "))

     if op == "+":
          print(user_input_1+user_input_2)
     elif op == "-":
          print(user_input_1-user_input_2)
     elif op == "*":
          print(user_input_1*user_input_2)
     elif op == "/":
          print(user_input_1/user_input_2)
     elif op == "%":
          print(user_input_1/100*user_input_2)
     elif op == "^":
         print(user_input_1**user_input_2)
     else:
          print("SYNTAX ERROR!!!!")

# %%
#----------------------- ASSIGMENT marks ------------#
subject1 = int(input('WRITE MATHS SUBJECT: '))
subject2 = int(input('WRITE BIO UBJECT: '))
subject3 = int(input('WRITE CHEMISTRY SUBJECT: '))
subject4 = int(input('WRITE ISLAMIAT SUBJECT: '))
subject5 = int(input('WRITE P.S SUBJECT: '))
subjects = [subject1, subject2, subject3, subject4, subject5]
max_marks = max(subjects)
print(f"The highest marks are: {max_marks}")

# %%
#----------------------- IF ELSE CONDITION STATEMENT -------------------#
marks = int(input("write marks"))
if marks >= 50:
     print("pass")
else:
     print("failed")

# %%
#----------------------- ATM ASSIGNMENT 1 -------------- #
balance = 50000
user_name = "zulfiqar"
user_password = "1234"
user_name = input("WRITE YOUR NAME: ")
user_password = input("WRITE YOUR PASSWORD: ")
if user_name == "zulfiqar" and user_password == "1234":
     print("WELCOME ZULFIQAR.")
     print("WRITE ('AMOUNT') TO WITHDRAW OR ('TOTAL') FOR ACCOUNT INFO")
     user_command_2 = input(("WRITE ('AMOUNT') TO WITHDRAW OR ('TOTAL') FOR ACCOUNT INFO"))
     if user_command_2 == "amount":
          print("write amount to withdraw : ")
          amount = float(input("write amount to withdraw : "))
          if amount <= balance:
               print(f"Dear customer you have  debited the amount of \n{amount}Rs and your current balance is {balance-amount}Rs")
               print("THANKS FOR USING OUR ATM!")
          else:
                print("INPUT AMOUNT IS  HIGHER THAN YOUR BALANCE!!")
     elif user_command_2  == "total":
          print("YOUR CURRENT BALANCE IS ",balance,"Rs")
     else:
               print("I DO NOT UNDERSTAND THAT!!")
else:
     print("WRONG PASSWORD OR USERNAME!!")

# %%
#-----------------------TOPPER ASSIGMENT 2 ------------#
print("TO EXIT WRITE 0")

while True:
 
 marks = float(input("WRITE YOUR MARKS: ")) 

 if marks >= 101:
    print("WRONG!! MARKS ENTERED ARE  HIGHER THAN 100 GRADE NOT AVAILABLE!!!!!!!!!")
 elif marks >= 90:
    print("TOPPER OF THE CLASS! KEEP SHINING !!!!!!")
 elif marks >= 70:
    print("EXELLENT EFFORT!!!! ")
 elif marks >=50:
    print("NEED IMPROVENT!!!")
 elif marks == 0:
    print("CLOSED!!")
    break
 else:
     print("NEEDS EXTRA SUPPORT YOU FAILED!!!!!")

# %%
#----------------------- COFFEE MACHINE ASSIGNMENT 3 -------------#
print("hello welcome to SMIT cafe what do you need.\n(1)for tea \n(2)for coffee \n(3) for hot chocolote")
user_choice = int(input("WHAT WOULD YOU HAVE!")) 
if user_choice == 1:
     print("HERE YOU GO ENJOY YOUR TEA!!")
elif user_choice == 2:
     print("HERE IS YOUR COFFEE.")
elif user_choice ==3:
     print("Hot chocolate coming up! ENJOY  :)")
else:
     print("INVALID SELECTION!!")

# %%
#----------------------- TRAFFIC SIGNALS ASIGMENT 4 ----------#
while signals:
 signals = input(("red","green","yellow"))  
 if signals.lower() == "red":
     print('STOP!!')
 elif signals.lower() == "yellow":
     print("BE READY!")
 elif signals.lower() == "green":
     print("LETS GOOOOO!")
 else:
     print("signal malfunctions!!! :(")
     break

# %%
#----------------------- THEME PARK ASSIGMENT 5 -----------#
user_age = int(input("WRITE YOUR AGE ; "))
user_height = int(input("WRITE YOUR HEIGHT IN CM : "))
if user_age >= 12 and user_height >= 120:
     print("YOU CAN RIDE!! ")
elif user_age < 12:
     print("you are too young for this ride!")
elif user_height < 120:
     print("you are too short for this ride!")
else:
     print("INVALID INPUT")

# %%
#----------------------- SEASONS ASSIGNMENT 6 -----------------------#
while True:
     places = input(" WRITE THE SEASON: ")
     places = places.lower()
     if places == "summer":
          print("GO TO BEACH!:)")
     elif places == "winter":
          print("LETS HIT THE MOUNTAIN! :) ")
     elif places == "autumn":
          print("TAKE A FOREST HIKE :)")
     elif places == "spring":
          print("VISIT THE GARDENS :)")
     else:
         print("WRONG SEASON ENTERED!!")
         break

# %%
#----------------------- SPEED CAR ASSIGMENT 7  ----------------------#
driver_speed = int(input('write your speed !!'))
if driver_speed <= 40:
     print("TOO SLOW KEEP MOVING!!")
elif driver_speed > 40 and driver_speed <= 80:
     print("SAFE SPEED :) ")
elif driver_speed > 80 and driver_speed <= 120:
     print("WARNING OVERSPEEDING!!")
elif driver_speed > 120:
     print("YOUR LICENSE IS SUSPENDED! ")

# %%
#----------------------- PIZZA CHOICE ASSIGNMENT 8 ----------------- #
while True:
     size   = input("WRITE SIZE OF PIZZA !")
     coupen = input("DO YOU HAVE COUPEN? ")
     size = size.lower()
     coupen = coupen.lower()
     if size == "large" and coupen == "yes":
          print("20% DISCOUNT APPLIED ON YOUR LARGE PIZZA! :) ")
          break
     elif coupen == "no":
          print(f"{size.upper()} PIZZA ORDERED WITHOUT ANY DICOUNT!")
          break
     elif size == "medium" and coupen == "yes":
          print("10% DISCOUNT APPLIED ON YOUR MEDIUM PIZZA!")
          break
     elif size == "small":
          print("SMALL PIZZA ORDERED! *NO DISCOUNT ON SMALL PIZZAs* ")
          break

# %%
#----------------------- HOTEL ROOM ASSIGNMENT 9 --------------------# 
print("WHAT TYPE OF ROOM YOU WANT? (SUITE,DELUXE,LUXURY)")
room = input("WHAT TYPE OF ROOM YOU WANT? (SUITE,DELUXE,LUXURY)")
room = room.lower()
if   room == "suite":
     print("LUXURY DISCOUNT APPLIED FOR SUITE !! ")
elif room == "deluxe":
     print("BREAKFAST INCLUDED FOR FREE IN DELUXE ROOM!!")
elif  room == "standard":
     print("BASIC STAY *NO DISCOUNT ON STANDARD ROOMS*")
else:
     print("WRONG SELECTION!!!")

# %%
#------------------------ GAME LEVEL ASSIGNMENT 10 -----------------#
print("Write your Score: ")
user_score = int(input("Write your Score: "))
print("Write your total coins.")
user_coin = int(input("Write your total coins."))
if user_score >= 1000 and user_coin >= 50:
     print("CONGRATS!!! New Level Unlocked!!") 
elif user_score >= 500 and user_coin < 50:
     print("HALFWAY THERE! Keep Playing!")
else:
     print("Wrong Input!!!")

# %%
#------------------------  ANY NUMBER  SUM ASSIGNEMT ---------------------#
n = int(input("write a number"))
sum = 0

for i in range(n+1):
     sum += i
print(f"Total sum of number {n} is : {sum}")

# %%
#-------------------------- FACTORIAL OF INPUT NUMBER ---------------------#
n = int(input("Enter number to find its factors:"))
factorial = 1
for i in range(1,n+1):
     factorial *= i

print(f"Factorial  of number {n} is : {factorial}")

# %%
#------------------------ PASSWORD 3 ATTEMPTS ----------------------#
attempts = 0
password = "1234"
while attempts < 3:
     user_password = input("Write password you have only 3 attempts")
     if user_password == password:
          print("CORRECT PASSWORD!")
          break
     else:
          print("ACCESS DENIED!")
          attempts += 1
else:
     print("NO ATTEMPTS LEFT!")

# %%
#----------------------- string ******** ---------------------#
for i in range(1,6):
     print("*"*i)

# %%
#------------------------ RANDOM NUMBER GUESSING --------------------#
import random
secret_number = random.randint(1,10)
while secret_number:
     user_guess = int(input("GUESS A NUMBER BETWEEN 1 TO 10! "))
     if user_guess < secret_number:
          print("THE NUMBER IS HIGHER THAN ",user_guess)
     elif user_guess > secret_number:
          print("THE NUMBER IS LESS THAN ", user_guess)
     elif user_guess == secret_number:
          print("CONGRATS YOU GOT IT!!!! THE NUMBER IS " , secret_number)
          break
     else:
          print("i dont understand that!")

# %%
name = input("write name")
for i in name:
     print(i)
# Out:
# z
# i
# l
# f
# i
# g
# a
# r

# %%
secret_num = 54
while secret_num:
     user_num = int(input("write a number"))
     if secret_num == user_num:
          print("WRITE NUMER GUESSED!!! 🥳")
          break
     else:
          print("WRONG NUMBER TRY AGIAIN!!!! 😕")
# Out:
# WRITE NUMER GUESSED!!!!!!!!!🥳🥳
